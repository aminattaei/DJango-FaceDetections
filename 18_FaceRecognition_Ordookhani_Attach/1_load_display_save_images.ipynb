# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./images/3.jpg') # bgr # 8bit

# %%
cv2.imshow('my image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img[:,:,[2,1,0]]) # rgb
plt.show()

# %%
cv2.imwrite('./images/new-image.png', img)
# Out:
# True
